# %%
# !pip install torch==2.5.0+cu124 torchvision==0.20.0+cu124 torchaudio==2.5.0+cu124 torchtext==0.18.0 torchdata==0.8.0 --extra-index-url https://download.pytorch.org/whl/cu124
# !pip install xformers==0.0.28.post2
# !pip install https://github.com/Dao-AILab/flash-attention/releases/download/v2.6.3/flash_attn-2.6.3+cu123torch2.3cxx11abiFALSE-cp310-cp310-linux_x86_64.whl

# %cd /content
# !git clone --recursive https://github.com/Microsoft/TRELLIS
# %cd /content/TRELLIS

# !pip install easydict rembg onnxruntime onnxruntime-gpu numpy==2.0.0 plyfile huggingface-hub safetensors
# !pip install git+https://github.com/NVlabs/nvdiffrast trimesh xatlas pyvista pymeshfix igraph spconv-cu120
# !pip install opencv-python imageio imageio-ffmpeg ffmpeg-python av
# !pip install git+https://github.com/NVIDIAGameWorks/kaolin
# !pip install git+https://github.com/SarahWeiii/diso
# !pip install git+https://github.com/EasternJournalist/utils3d.git@9a4eb15e4021b67b12c460c7057d642626897ec8
# !pip install https://huggingface.co/spaces/JeffreyXiang/TRELLIS/resolve/main/wheels/nvdiffrast-0.3.3-cp310-cp310-linux_x86_64.whl
# !pip install https://huggingface.co/spaces/JeffreyXiang/TRELLIS/resolve/main/wheels/diff_gaussian_rasterization-0.0.0-cp310-cp310-linux_x86_64.whl

# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/JeffreyXiang/TRELLIS-image-large/raw/main/pipeline.json -d /content/model -o pipeline.json
# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/JeffreyXiang/TRELLIS-image-large/raw/main/ckpts/slat_dec_gs_swin8_B_64l8gs32_fp16.json -d /content/model/ckpts -o slat_dec_gs_swin8_B_64l8gs32_fp16.json
# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/JeffreyXiang/TRELLIS-image-large/resolve/main/ckpts/slat_dec_gs_swin8_B_64l8gs32_fp16.safetensors -d /content/model/ckpts -o slat_dec_gs_swin8_B_64l8gs32_fp16.safetensors
# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/JeffreyXiang/TRELLIS-image-large/raw/main/ckpts/slat_dec_mesh_swin8_B_64l8m256c_fp16.json -d /content/model/ckpts -o slat_dec_mesh_swin8_B_64l8m256c_fp16.json
# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/JeffreyXiang/TRELLIS-image-large/resolve/main/ckpts/slat_dec_mesh_swin8_B_64l8m256c_fp16.safetensors -d /content/model/ckpts -o slat_dec_mesh_swin8_B_64l8m256c_fp16.safetensors
# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/JeffreyXiang/TRELLIS-image-large/raw/main/ckpts/slat_dec_rf_swin8_B_64l8r16_fp16.json -d /content/model/ckpts -o slat_dec_rf_swin8_B_64l8r16_fp16.json
# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/JeffreyXiang/TRELLIS-image-large/resolve/main/ckpts/slat_dec_rf_swin8_B_64l8r16_fp16.safetensors -d /content/model/ckpts -o slat_dec_rf_swin8_B_64l8r16_fp16.safetensors
# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/JeffreyXiang/TRELLIS-image-large/raw/main/ckpts/slat_enc_swin8_B_64l8_fp16.json -d /content/model/ckpts -o slat_enc_swin8_B_64l8_fp16.json
# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/JeffreyXiang/TRELLIS-image-large/resolve/main/ckpts/slat_enc_swin8_B_64l8_fp16.safetensors -d /content/model/ckpts -o slat_enc_swin8_B_64l8_fp16.safetensors
# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/JeffreyXiang/TRELLIS-image-large/raw/main/ckpts/slat_flow_img_dit_L_64l8p2_fp16.json -d /content/model/ckpts -o slat_flow_img_dit_L_64l8p2_fp16.json
# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/JeffreyXiang/TRELLIS-image-large/resolve/main/ckpts/slat_flow_img_dit_L_64l8p2_fp16.safetensors -d /content/model/ckpts -o slat_flow_img_dit_L_64l8p2_fp16.safetensors
# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/JeffreyXiang/TRELLIS-image-large/raw/main/ckpts/ss_dec_conv3d_16l8_fp16.json -d /content/model/ckpts -o ss_dec_conv3d_16l8_fp16.json
# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/JeffreyXiang/TRELLIS-image-large/resolve/main/ckpts/ss_dec_conv3d_16l8_fp16.safetensors -d /content/model/ckpts -o ss_dec_conv3d_16l8_fp16.safetensors
# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/JeffreyXiang/TRELLIS-image-large/raw/main/ckpts/ss_enc_conv3d_16l8_fp16.json -d /content/model/ckpts -o ss_enc_conv3d_16l8_fp16.json
# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/JeffreyXiang/TRELLIS-image-large/resolve/main/ckpts/ss_enc_conv3d_16l8_fp16.safetensors -d /content/model/ckpts -o ss_enc_conv3d_16l8_fp16.safetensors
# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/JeffreyXiang/TRELLIS-image-large/raw/main/ckpts/ss_flow_img_dit_L_16l8_fp16.json -d /content/model/ckpts -o ss_flow_img_dit_L_16l8_fp16.json
# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/JeffreyXiang/TRELLIS-image-large/resolve/main/ckpts/ss_flow_img_dit_L_16l8_fp16.safetensors -d /content/model/ckpts -o ss_flow_img_dit_L_16l8_fp16.safetensors
# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://github.com/facebookresearch/dinov2/zipball/main -d /root/.cache/torch/hub -o main.zip
# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://dl.fbaipublicfiles.com/dinov2/dinov2_vitl14/dinov2_vitl14_reg4_pretrain.pth -d /root/.cache/torch/hub/checkpoints -o dinov2_vitl14_reg4_pretrain.pth

# %%
# %cd /content
# !pip wheel git+https://github.com/NVIDIAGameWorks/kaolin
# Out:
# /content/TRELLIS-venv/lib/python3.10/site-packages/IPython/core/magics/osm.py:417: UserWarning: This is now an optional IPython functionality, setting dhist requires you to install the `pickleshare` library.
#   self.shell.db['dhist'] = compress_dhist(dhist)[-100:]
# /content
# Collecting git+https://github.com/NVIDIAGameWorks/kaolin
#   Cloning https://github.com/NVIDIAGameWorks/kaolin to /tmp/pip-req-build-zzff4217
#   Running command git clone --filter=blob:none --quiet https://github.com/NVIDIAGameWorks/kaolin /tmp/pip-req-build-zzff4217
#   Resolved https://github.com/NVIDIAGameWorks/kaolin to commit ba9824e394b074099fbae7d5218e68c6362e9ecf
#   Running command git submodule update --init --recursive -q
#   Preparing metadata (setup.py) ... done
# Collecting ipycanvas (from kaolin==0.17.0)
#   Using cached ipycanvas-0.13.3-py2.py3-none-any.whl.metadata (6.3 kB)
# Collecting ipyevents (from kaolin==0.17.0)
#   Using cached ipyevents-2.0.2-py3-none-any.whl.metadata (2.9 kB)
# Collecting jupyter_client<8 (from kaolin==0.17.0)
#   Using cached jupyter_client-7.4.9-py3-none-any.whl.metadata (8.5 kB)
# Collecting flask (from kaolin==0.17.0)
#   Downloading flask-3.1.0-py3-none-any.whl.metadata (2.7 kB)
# Collecting tornado (from kaolin==0.17.0)
#   Using cached tornado-6.4.2-cp38-abi3-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (2.5 kB)
# Collecting comm>=0.1.3 (from kaolin==0.17.0)
#   Using cached comm-0.2.2-py3-none-any.whl.metadata (3.7 kB)
# Collecting usd-core (from kaolin==0.17.0)
#   Using cached usd_core-24.11-cp310-none-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting numpy<2.0 (from kaolin==0.17.0)
#   Using cached numpy-1.26.4-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (61 kB)
# Collecting pybind11 (from kaolin==0.17.0)
#   Using cached pybind11-2.13.6-py3-none-any.whl.metadata (9.5 kB)
# Collecting Pillow>=8.0.0 (from kaolin==0.17.0)
#   Using cached pillow-11.0.0-cp310-cp310-manylinux_2_28_x86_64.whl.metadata (9.1 kB)
# Collecting tqdm>=4.51.0 (from kaolin==0.17.0)
#   Using cached tqdm-4.67.1-py3-none-any.whl.metadata (57 kB)
# Collecting scipy (from kaolin==0.17.0)
#   Using cached scipy-1.14.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (60 kB)
# Collecting pygltflib (from kaolin==0.17.0)
#   Using cached pygltflib-1.16.3-py3-none-any.whl
# Collecting warp-lang (from kaolin==0.17.0)
#   Using cached warp_lang-1.5.0-py3-none-manylinux2014_x86_64.whl.metadata (25 kB)
# Collecting ipython (from kaolin==0.17.0)
#   Using cached ipython-8.30.0-py3-none-any.whl.metadata (4.9 kB)
# Collecting traitlets>=4 (from comm>=0.1.3->kaolin==0.17.0)
#   Using cached traitlets-5.14.3-py3-none-any.whl.metadata (10 kB)
# Collecting entrypoints (from jupyter_client<8->kaolin==0.17.0)
#   Using cached entrypoints-0.4-py3-none-any.whl.metadata (2.6 kB)
# Collecting jupyter-core>=4.9.2 (from jupyter_client<8->kaolin==0.17.0)
#   Using cached jupyter_core-5.7.2-py3-none-any.whl.metadata (3.4 kB)
# Collecting nest-asyncio>=1.5.4 (from jupyter_client<8->kaolin==0.17.0)
#   Using cached nest_asyncio-1.6.0-py3-none-any.whl.metadata (2.8 kB)
# Collecting python-dateutil>=2.8.2 (from jupyter_client<8->kaolin==0.17.0)
#   Using cached python_dateutil-2.9.0.post0-py2.py3-none-any.whl.metadata (8.4 kB)
# Collecting pyzmq>=23.0 (from jupyter_client<8->kaolin==0.17.0)
#   Using cached pyzmq-26.2.0-cp310-cp310-manylinux_2_28_x86_64.whl.metadata (6.2 kB)
# Collecting Werkzeug>=3.1 (from flask->kaolin==0.17.0)
#   Using cached werkzeug-3.1.3-py3-none-any.whl.metadata (3.7 kB)
# Collecting Jinja2>=3.1.2 (from flask->kaolin==0.17.0)
#   Using cached jinja2-3.1.4-py3-none-any.whl.metadata (2.6 kB)
# Collecting itsdangerous>=2.2 (from flask->kaolin==0.17.0)
#   Using cached itsdangerous-2.2.0-py3-none-any.whl.metadata (1.9 kB)
# Collecting click>=8.1.3 (from flask->kaolin==0.17.0)
#   Using cached click-8.1.7-py3-none-any.whl.metadata (3.0 kB)
# Collecting blinker>=1.9 (from flask->kaolin==0.17.0)
#   Using cached blinker-1.9.0-py3-none-any.whl.metadata (1.6 kB)
# Collecting ipywidgets<9,>=7.6.0 (from ipycanvas->kaolin==0.17.0)
#   Using cached ipywidgets-8.1.5-py3-none-any.whl.metadata (2.3 kB)
# Collecting decorator (from ipython->kaolin==0.17.0)
#   Using cached decorator-5.1.1-py3-none-any.whl.metadata (4.0 kB)
# Collecting exceptiongroup (from ipython->kaolin==0.17.0)
#   Using cached exceptiongroup-1.2.2-py3-none-any.whl.metadata (6.6 kB)
# Collecting jedi>=0.16 (from ipython->kaolin==0.17.0)
#   Using cached jedi-0.19.2-py2.py3-none-any.whl.metadata (22 kB)
# Collecting matplotlib-inline (from ipython->kaolin==0.17.0)
#   Using cached matplotlib_inline-0.1.7-py3-none-any.whl.metadata (3.9 kB)
# Collecting pexpect>4.3 (from ipython->kaolin==0.17.0)
#   Using cached pexpect-4.9.0-py2.py3-none-any.whl.metadata (2.5 kB)
# Collecting prompt_toolkit<3.1.0,>=3.0.41 (from ipython->kaolin==0.17.0)
#   Using cached prompt_toolkit-3.0.48-py3-none-any.whl.metadata (6.4 kB)
# Collecting pygments>=2.4.0 (from ipython->kaolin==0.17.0)
#   Using cached pygments-2.18.0-py3-none-any.whl.metadata (2.5 kB)
# Collecting stack_data (from ipython->kaolin==0.17.0)
#   Using cached stack_data-0.6.3-py3-none-any.whl.metadata (18 kB)
# Collecting typing_extensions>=4.6 (from ipython->kaolin==0.17.0)
#   Using cached typing_extensions-4.12.2-py3-none-any.whl.metadata (3.0 kB)
# Collecting dataclasses-json>=0.0.25 (from pygltflib->kaolin==0.17.0)
#   Using cached dataclasses_json-0.6.7-py3-none-any.whl.metadata (25 kB)
# Collecting deprecated (from pygltflib->kaolin==0.17.0)
#   Using cached Deprecated-1.2.15-py2.py3-none-any.whl.metadata (5.5 kB)
# Collecting marshmallow<4.0.0,>=3.18.0 (from dataclasses-json>=0.0.25->pygltflib->kaolin==0.17.0)
#   Using cached marshmallow-3.23.1-py3-none-any.whl.metadata (7.5 kB)
# Collecting typing-inspect<1,>=0.4.0 (from dataclasses-json>=0.0.25->pygltflib->kaolin==0.17.0)
#   Using cached typing_inspect-0.9.0-py3-none-any.whl.metadata (1.5 kB)
# Collecting widgetsnbextension~=4.0.12 (from ipywidgets<9,>=7.6.0->ipycanvas->kaolin==0.17.0)
#   Using cached widgetsnbextension-4.0.13-py3-none-any.whl.metadata (1.6 kB)
# Collecting jupyterlab-widgets~=3.0.12 (from ipywidgets<9,>=7.6.0->ipycanvas->kaolin==0.17.0)
#   Using cached jupyterlab_widgets-3.0.13-py3-none-any.whl.metadata (4.1 kB)
# Collecting parso<0.9.0,>=0.8.4 (from jedi>=0.16->ipython->kaolin==0.17.0)
#   Using cached parso-0.8.4-py2.py3-none-any.whl.metadata (7.7 kB)
# Collecting MarkupSafe>=2.0 (from Jinja2>=3.1.2->flask->kaolin==0.17.0)
#   Using cached MarkupSafe-3.0.2-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (4.0 kB)
# Collecting platformdirs>=2.5 (from jupyter-core>=4.9.2->jupyter_client<8->kaolin==0.17.0)
#   Using cached platformdirs-4.3.6-py3-none-any.whl.metadata (11 kB)
# Collecting ptyprocess>=0.5 (from pexpect>4.3->ipython->kaolin==0.17.0)
#   Using cached ptyprocess-0.7.0-py2.py3-none-any.whl.metadata (1.3 kB)
# Collecting wcwidth (from prompt_toolkit<3.1.0,>=3.0.41->ipython->kaolin==0.17.0)
#   Using cached wcwidth-0.2.13-py2.py3-none-any.whl.metadata (14 kB)
# Collecting six>=1.5 (from python-dateutil>=2.8.2->jupyter_client<8->kaolin==0.17.0)
#   Using cached six-1.17.0-py2.py3-none-any.whl.metadata (1.7 kB)
# Collecting wrapt<2,>=1.10 (from deprecated->pygltflib->kaolin==0.17.0)
#   Using cached wrapt-1.17.0-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (6.4 kB)
# Collecting executing>=1.2.0 (from stack_data->ipython->kaolin==0.17.0)
#   Using cached executing-2.1.0-py2.py3-none-any.whl.metadata (8.9 kB)
# Collecting asttokens>=2.1.0 (from stack_data->ipython->kaolin==0.17.0)
#   Using cached asttokens-3.0.0-py3-none-any.whl.metadata (4.7 kB)
# Collecting pure-eval (from stack_data->ipython->kaolin==0.17.0)
#   Using cached pure_eval-0.2.3-py3-none-any.whl.metadata (6.3 kB)
# Collecting packaging>=17.0 (from marshmallow<4.0.0,>=3.18.0->dataclasses-json>=0.0.25->pygltflib->kaolin==0.17.0)
#   Using cached packaging-24.2-py3-none-any.whl.metadata (3.2 kB)
# Collecting mypy-extensions>=0.3.0 (from typing-inspect<1,>=0.4.0->dataclasses-json>=0.0.25->pygltflib->kaolin==0.17.0)
#   Using cached mypy_extensions-1.0.0-py3-none-any.whl.metadata (1.1 kB)
# Using cached comm-0.2.2-py3-none-any.whl (7.2 kB)
# Using cached jupyter_client-7.4.9-py3-none-any.whl (133 kB)
# Using cached numpy-1.26.4-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (18.2 MB)
# Using cached pillow-11.0.0-cp310-cp310-manylinux_2_28_x86_64.whl (4.4 MB)
# Using cached tornado-6.4.2-cp38-abi3-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (437 kB)
# Using cached tqdm-4.67.1-py3-none-any.whl (78 kB)
# Downloading flask-3.1.0-py3-none-any.whl (102 kB)
# Using cached ipycanvas-0.13.3-py2.py3-none-any.whl (125 kB)
# Using cached ipyevents-2.0.2-py3-none-any.whl (101 kB)
# Using cached ipython-8.30.0-py3-none-any.whl (820 kB)
# Using cached pybind11-2.13.6-py3-none-any.whl (243 kB)
# Using cached scipy-1.14.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (41.2 MB)
# Using cached usd_core-24.11-cp310-none-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (25.4 MB)
# Using cached warp_lang-1.5.0-py3-none-manylinux2014_x86_64.whl (84.6 MB)
# Using cached blinker-1.9.0-py3-none-any.whl (8.5 kB)
# Using cached click-8.1.7-py3-none-any.whl (97 kB)
# Using cached dataclasses_json-0.6.7-py3-none-any.whl (28 kB)
# Using cached ipywidgets-8.1.5-py3-none-any.whl (139 kB)
# Using cached itsdangerous-2.2.0-py3-none-any.whl (16 kB)
# Using cached jedi-0.19.2-py2.py3-none-any.whl (1.6 MB)
# Using cached jinja2-3.1.4-py3-none-any.whl (133 kB)
# Using cached jupyter_core-5.7.2-py3-none-any.whl (28 kB)
# Using cached nest_asyncio-1.6.0-py3-none-any.whl (5.2 kB)
# Using cached pexpect-4.9.0-py2.py3-none-any.whl (63 kB)
# Using cached prompt_toolkit-3.0.48-py3-none-any.whl (386 kB)
# Using cached pygments-2.18.0-py3-none-any.whl (1.2 MB)
# Using cached python_dateutil-2.9.0.post0-py2.py3-none-any.whl (229 kB)
# Using cached pyzmq-26.2.0-cp310-cp310-manylinux_2_28_x86_64.whl (868 kB)
# Using cached traitlets-5.14.3-py3-none-any.whl (85 kB)
# Using cached typing_extensions-4.12.2-py3-none-any.whl (37 kB)
# Using cached werkzeug-3.1.3-py3-none-any.whl (224 kB)
# Using cached decorator-5.1.1-py3-none-any.whl (9.1 kB)
# Using cached Deprecated-1.2.15-py2.py3-none-any.whl (9.9 kB)
# Using cached entrypoints-0.4-py3-none-any.whl (5.3 kB)
# Using cached exceptiongroup-1.2.2-py3-none-any.whl (16 kB)
# Using cached matplotlib_inline-0.1.7-py3-none-any.whl (9.9 kB)
# Using cached stack_data-0.6.3-py3-none-any.whl (24 kB)
# Using cached asttokens-3.0.0-py3-none-any.whl (26 kB)
# Using cached executing-2.1.0-py2.py3-none-any.whl (25 kB)
# Using cached jupyterlab_widgets-3.0.13-py3-none-any.whl (214 kB)
# Using cached MarkupSafe-3.0.2-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (20 kB)
# Using cached marshmallow-3.23.1-py3-none-any.whl (49 kB)
# Using cached parso-0.8.4-py2.py3-none-any.whl (103 kB)
# Using cached platformdirs-4.3.6-py3-none-any.whl (18 kB)
# Using cached ptyprocess-0.7.0-py2.py3-none-any.whl (13 kB)
# Using cached six-1.17.0-py2.py3-none-any.whl (11 kB)
# Using cached typing_inspect-0.9.0-py3-none-any.whl (8.8 kB)
# Using cached widgetsnbextension-4.0.13-py3-none-any.whl (2.3 MB)
# Using cached wrapt-1.17.0-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (82 kB)
# Using cached pure_eval-0.2.3-py3-none-any.whl (11 kB)
# Using cached wcwidth-0.2.13-py2.py3-none-any.whl (34 kB)
# Using cached mypy_extensions-1.0.0-py3-none-any.whl (4.7 kB)
# Using cached packaging-24.2-py3-none-any.whl (65 kB)
# Saved ./comm-0.2.2-py3-none-any.whl
# Saved ./jupyter_client-7.4.9-py3-none-any.whl
# Saved ./numpy-1.26.4-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl
# Saved ./pillow-11.0.0-cp310-cp310-manylinux_2_28_x86_64.whl
# Saved ./tornado-6.4.2-cp38-abi3-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl
# Saved ./tqdm-4.67.1-py3-none-any.whl
# Saved ./flask-3.1.0-py3-none-any.whl
# Saved ./ipycanvas-0.13.3-py2.py3-none-any.whl
# Saved ./ipyevents-2.0.2-py3-none-any.whl
# Saved ./ipython-8.30.0-py3-none-any.whl
# Saved ./pybind11-2.13.6-py3-none-any.whl
# Saved ./pygltflib-1.16.3-py3-none-any.whl
# Saved ./scipy-1.14.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl
# Saved ./usd_core-24.11-cp310-none-manylinux_2_17_x86_64.manylinux2014_x86_64.whl
# Saved ./warp_lang-1.5.0-py3-none-manylinux2014_x86_64.whl
# Saved ./blinker-1.9.0-py3-none-any.whl
# Saved ./click-8.1.7-py3-none-any.whl
# Saved ./dataclasses_json-0.6.7-py3-none-any.whl
# Saved ./ipywidgets-8.1.5-py3-none-any.whl
# Saved ./itsdangerous-2.2.0-py3-none-any.whl
# Saved ./jedi-0.19.2-py2.py3-none-any.whl
# Saved ./jinja2-3.1.4-py3-none-any.whl
# Saved ./jupyter_core-5.7.2-py3-none-any.whl
# Saved ./nest_asyncio-1.6.0-py3-none-any.whl
# Saved ./pexpect-4.9.0-py2.py3-none-any.whl
# Saved ./prompt_toolkit-3.0.48-py3-none-any.whl
# Saved ./pygments-2.18.0-py3-none-any.whl
# Saved ./python_dateutil-2.9.0.post0-py2.py3-none-any.whl
# Saved ./pyzmq-26.2.0-cp310-cp310-manylinux_2_28_x86_64.whl
# Saved ./traitlets-5.14.3-py3-none-any.whl
# Saved ./typing_extensions-4.12.2-py3-none-any.whl
# Saved ./werkzeug-3.1.3-py3-none-any.whl
# Saved ./decorator-5.1.1-py3-none-any.whl
# Saved ./Deprecated-1.2.15-py2.py3-none-any.whl
# Saved ./entrypoints-0.4-py3-none-any.whl
# Saved ./exceptiongroup-1.2.2-py3-none-any.whl
# Saved ./matplotlib_inline-0.1.7-py3-none-any.whl
# Saved ./stack_data-0.6.3-py3-none-any.whl
# Saved ./asttokens-3.0.0-py3-none-any.whl
# Saved ./executing-2.1.0-py2.py3-none-any.whl
# Saved ./jupyterlab_widgets-3.0.13-py3-none-any.whl
# Saved ./MarkupSafe-3.0.2-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl
# Saved ./marshmallow-3.23.1-py3-none-any.whl
# Saved ./parso-0.8.4-py2.py3-none-any.whl
# Saved ./platformdirs-4.3.6-py3-none-any.whl
# Saved ./ptyprocess-0.7.0-py2.py3-none-any.whl
# Saved ./six-1.17.0-py2.py3-none-any.whl
# Saved ./typing_inspect-0.9.0-py3-none-any.whl
# Saved ./widgetsnbextension-4.0.13-py3-none-any.whl
# Saved ./wrapt-1.17.0-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl
# Saved ./pure_eval-0.2.3-py3-none-any.whl
# Saved ./wcwidth-0.2.13-py2.py3-none-any.whl
# Saved ./mypy_extensions-1.0.0-py3-none-any.whl
# Saved ./packaging-24.2-py3-none-any.whl
# Building wheels for collected packages: kaolin
#   Building wheel for kaolin (setup.py) ... done
#   Created wheel for kaolin: filename=kaolin-0.17.0-cp310-cp310-linux_x86_64.whl size=12835228 sha256=b61067a7623bd41d6231bf66e8725c0365cdf9dbec7e7f0d8ce6ee85af9b4a7b
#   Stored in directory: /tmp/pip-ephem-wheel-cache-phreli6q/wheels/66/70/dc/15e641cb1f1b05a126599baa877b24a4acf5427a48dd08c327
# Successfully built kaolin

# %%
# %cd /content/TRELLIS

import numpy as np
import torch
import imageio
from typing import *
from PIL import Image
from easydict import EasyDict as edict
from trellis.pipelines import TrellisImageTo3DPipeline
from trellis.representations import Gaussian, MeshExtractResult
from trellis.utils import render_utils, postprocessing_utils

MAX_SEED = np.iinfo(np.int32).max
TMP_DIR = "/content"

def preprocess_image(image_path: str) -> Tuple[str, Image.Image]:
    trial_id = "trellis-tost"
    image = Image.open(image_path).convert("RGBA")
    processed_image = pipeline.preprocess_image(image)
    processed_image.save(f"{TMP_DIR}/{trial_id}.png")
    return trial_id, processed_image

def pack_state(gs: Gaussian, mesh: MeshExtractResult, trial_id: str) -> dict:
    return {
        'gaussian': {
            **gs.init_params,
            '_xyz': gs._xyz.cpu().numpy(),
            '_features_dc': gs._features_dc.cpu().numpy(),
            '_scaling': gs._scaling.cpu().numpy(),
            '_rotation': gs._rotation.cpu().numpy(),
            '_opacity': gs._opacity.cpu().numpy(),
        },
        'mesh': {
            'vertices': mesh.vertices.cpu().numpy(),
            'faces': mesh.faces.cpu().numpy(),
        },
        'trial_id': trial_id,
    }

def unpack_state(state: dict) -> Tuple[Gaussian, edict, str]:
    gs = Gaussian(
        aabb=state['gaussian']['aabb'],
        sh_degree=state['gaussian']['sh_degree'],
        mininum_kernel_size=state['gaussian']['mininum_kernel_size'],
        scaling_bias=state['gaussian']['scaling_bias'],
        opacity_bias=state['gaussian']['opacity_bias'],
        scaling_activation=state['gaussian']['scaling_activation'],
    )
    gs._xyz = torch.tensor(state['gaussian']['_xyz'], device='cuda')
    gs._features_dc = torch.tensor(state['gaussian']['_features_dc'], device='cuda')
    gs._scaling = torch.tensor(state['gaussian']['_scaling'], device='cuda')
    gs._rotation = torch.tensor(state['gaussian']['_rotation'], device='cuda')
    gs._opacity = torch.tensor(state['gaussian']['_opacity'], device='cuda')

    mesh = edict(
        vertices=torch.tensor(state['mesh']['vertices'], device='cuda'),
        faces=torch.tensor(state['mesh']['faces'], device='cuda'),
    )

    return gs, mesh, state['trial_id']

def image_to_3d(image_path: str, seed: int = 0, randomize_seed: bool = True,
                ss_guidance_strength: float = 7.5, ss_sampling_steps: int = 12,
                slat_guidance_strength: float = 3.0, slat_sampling_steps: int = 12) -> Tuple[dict, str]:
    trial_id, _ = preprocess_image(image_path)
    if randomize_seed:
        seed = np.random.randint(0, MAX_SEED)

    outputs = pipeline.run(
        Image.open(f"{TMP_DIR}/{trial_id}.png"),
        seed=seed,
        formats=["gaussian", "mesh"],
        preprocess_image=False,
        sparse_structure_sampler_params={
            "steps": ss_sampling_steps,
            "cfg_strength": ss_guidance_strength,
        },
        slat_sampler_params={
            "steps": slat_sampling_steps,
            "cfg_strength": slat_guidance_strength,
        },
    )

    video = render_utils.render_video(outputs['gaussian'][0], num_frames=120)['color']
    video_geo = render_utils.render_video(outputs['mesh'][0], num_frames=120)['normal']
    video = [np.concatenate([video[i], video_geo[i]], axis=1) for i in range(len(video))]
    trial_id = "trellis-tost"
    video_path = f"{TMP_DIR}/{trial_id}.mp4"
    imageio.mimsave(video_path, video, fps=15)

    state = pack_state(outputs['gaussian'][0], outputs['mesh'][0], str(trial_id))
    return state, video_path

def extract_glb(state: dict, mesh_simplify: float = 0.95, texture_size: int = 1024) -> str:
    gs, mesh, trial_id = unpack_state(state)
    glb = postprocessing_utils.to_glb(gs, mesh, simplify=mesh_simplify, texture_size=texture_size, verbose=False)
    glb_path = f"{TMP_DIR}/{trial_id}.glb"
    glb.export(glb_path)
    return glb_path

with torch.inference_mode():
    pipeline = TrellisImageTo3DPipeline.from_pretrained("/content/model")
    pipeline.cuda()

input_image = "/content/TRELLIS/T.png"
seed = 0
randomize_seed = True
ss_guidance_strength = 7.5
ss_sampling_steps = 12
slat_guidance_strength = 3.0
slat_sampling_steps = 12
mesh_simplify = 0.95
texture_size = 1024

state, video_path = image_to_3d(image_path=input_image, 
                                seed=seed, 
                                randomize_seed=randomize_seed, 
                                ss_guidance_strength=ss_guidance_strength, 
                                ss_sampling_steps=ss_sampling_steps,
                                slat_guidance_strength=slat_guidance_strength,
                                slat_sampling_steps=slat_sampling_steps)
glb_path = extract_glb(state=state, mesh_simplify=mesh_simplify, texture_size=texture_size)
